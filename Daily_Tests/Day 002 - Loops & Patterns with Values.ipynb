# %%
#Q1
for i in range(3):
 for j in range(2):
  print(i + j, end=" ")
# Out:
# 0 1 1 2 2 3

# %%
#Q2.
for i in range(1,5):
 print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
#Q3.
i=1
while i<=5:
 print(i,end=" ")
 i+=2
# Out:
# 1 3 5

# %%
#Q4.
for i in range(5,0,-2):
 print(i,end=" ")
# Out:
# 5 3 1

# %%
#Q5.
for i in range(1,4):
 for j in range(i):
  print(j,end="")
 print()
# Out:
# 0
# 01
# 012

# %%
#Q6.
for i in range(3):
 print(i)
else:
 print("Done")
# Out:
# 0
# 1
# 2
# Done

# %%
#Q7.
for i in range(1,4):
 for j in range(1,4):
  if(i==j):
    print("*",end="")
  else:
    print("-",end="")
 print()
# Out:
# *--
# -*-
# --*

# %%
#Q8.
s=0
for i in range(1,6):
 s+=i
print(s)
# Out:
# 15

# %%
#Q9.
for i in range(2):
 for j in range(2):
  print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
#Q10.
for i in range(1,5):
 print(i*"#")
# Out:
# #
# ##
# ###
# ####

# %%
#Q11.
for i in range(1,4):
 for j in range(1,i+1):
  print(i,end="")
 print()
# Out:
# 1
# 22
# 333

# %%
#Q12.
i=0
while i<3:
 print(i,end=" ")
 i+=1
else:
 print("End")
# Out:
# 0 1 2 End

# %%
#Q13.
for i in range(1,4):
 print(" "*(4-i)+"*"*i)
# Out:
#    *
#   **
#  ***

# %%
#Q14.
for i in range(1,5):
 if i==3:
  continue
 print(i,end=" ")
# Out:
# 1 2 4

# %%
#Q15.
for i in range(3):
 for j in range(3):
  if j==1:
    break
    print(j,end="")
 print()

# %%
#Q16.
for i in range(1,4):
 print("* "*i)
# Out:
# *
# * *
# * * *

# %%
#Q17.
x=1
for i in range(3):
 x*=2
print(x)
# Out:
# 8

# %%
#Q18.
for i in range(1,6):
 if i%2==0:
  print(i,end=" ")
# Out:
# 2 4

# %%
#Q19.
for i in range(3):
 print(chr(65+i),end=" ")
# Out:
# A B C

# %%
#Q20.
for i in range(1,4):
 for j in range(1,4):
  print(i*j,end=" ")
 print()
# Out:
# 1 2 3
# 2 4 6
# 3 6 9

# %%
#Q21.
for i in range(3):
 print(i)
if i==1:
  break
# Out:
# 0
# 1
# 2
#   File "/tmp/ipykernel_6091/2325665242.py", line 5
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
#Q22.
for i in range(1,4):
 print(str(i)*i)
# Out:
# 1
# 22
# 333

# %%
#Q23.
for i in range(1,5):
 print(i%2,end=" ")
# Out:
# 1 0 1 0

# %%
#Q24.
for i in range(4):
 print("*"*(4-i))
# Out:
# ****
# ***
# **
# *

# %%
#Q25.
for i in range(1,5):
 for j in range(i):
  print("*",end="")
 print()
# Out:
# *
# **
# ***
# ****

# %%
#Q26.
for i in range(1,4):
 for j in range(1,4):
  print(i+j,end=" ")
print()
# Out:
# 2 3 4 3 4 5 4 5 6

# %%
#Q27
i=5
while i>0:
 print(i,end=" ")
 i-=2
# Out:
# 5 3 1

# %%
#Q28.
for i in range(1,4):
 print("*"*(2*i-1))
# Out:
# *
# ***
# *****

# %%
#Q29.
count=0
for i in range(3):
 for j in range(2):
  count+=1
print(count)
# Out:
# 6

# %%
#Q30.
for i in range(1,5):
 print(i,end="")
 print("*")
# Out:
# 1*
# 2*
# 3*
# 4*
