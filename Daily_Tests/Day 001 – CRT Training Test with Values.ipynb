# %%
a = 10
b = a
a += 5
print(a, b)
# Out:
# 15 10

# %%
print(2 + 3 * 2 ** 2)
# Out:
# 14

# %%
for i in range(3):
  i += 2
print(i, end=' ')
# Out:
# 4

# %%
i = 0
while i < 3:
 print(i, end=' ')

# %%
print(True + False + True)
# Out:
# 2

# %%
for i in range(1, 5):
 if i == 3:
    continue
 print(i, end=' ')
# Out:
# 1 2 4

# %%
print(10 / 2 * 3)
# Out:
# 15.0

# %%
i = 1
while i < 10:
 i *= 2
print(i)
# Out:
# 16

# %%
for i in range(2):
 for j in range(2):
  print(i + j, end=' ')
# Out:
# 0 1 1 2

# %%
print(5 > 3 == True)
# Out:
# False

# %%
a = 3
b = 4
print(a * b // 2)
# Out:
# 6

# %%
a = 3
b = 4
print(a * b // 2)
# Out:
# 6

# %%
i = 5
while i:
 print(i, end=' ')
 i -=

# %%
print(not(4 > 2 and 3 < 1))
# Out:
# True

# %%
for i in range(3):
 for j in range(i):
  print(j, end=' ')
# Out:
# 0 0 1

# %%
print(3 + 4 * 2 // 2)
# Out:
# 7

# %%
for i in range(3):
 print(i, end='')
# Out:
# 012

# %%
a = 5
print(a == 5 or a < 2)
# Out:
# True

# %%
i = 1
while i < 5:
 print(i, end=' ')
 i += 1
# Out:
# 1 2 3 4

# %%
print(2 ** 3 ** 1)
# Out:
# 8

# %%
for i in range(2):
 for j in range(2):
  print('*', end='')
# Out:
# ****

# %%
print(5 > 2 and 10 < 3)
# Out:
# False

# %%
i = 10
while i > 0:
 i -= 3
 print(i, end=' ')
# Out:
# 7 4 1 -2

# %%
print(10 // 3 * 2)
# Out:
# 6

# %%
for i in range(1, 4):
 print(i + 1, end=' ')
# Out:
# 2 3 4

# %%
print(bool(0))
# Out:
# False

# %%
for i in range(3):
 if i == 1:
  break
 print(i, end=' ')
# Out:
# 0

# %%
a = 4
b = 2
print(a / b + a // b)
# Out:
# 4.0

# %%
i = 1
while i < 20:
 print(i, end=' ')
 i *= 3
# Out:
# 1 3 9

# %%
print(not(True and False))
# Out:
# True

# %%
print(7 % 3 + 2)
# Out:
# 3

# %%
x = 2
x *= 3
print(x)
# Out:
# 6

# %%
for i in range(5, 1, -2):
 print(i, end=' ')
# Out:
# 5 3

# %%
print(4 == 4 and 2 > 1)
# Out:
# True

# %%
i = 3
while i > 0:
 print(i, end=' ')
 i -= 1
# Out:
# 3 2 1

# %%
print(3 * 2 ** 2)
# Out:
# 12

# %%
for i in range(2):
 print(i + 5)
# Out:
# 5
# 6

# %%
print(False == 0)
# Out:
# True

# %%
a = 2
b = 5
print(a < b or b < 1)
# Out:
# True

# %%
for i in range(1, 5, 2):
 print(i, end=' ')
# Out:
# 1 3

# %%
print(9 // 2)
# Out:
# 4

# %%
i = 1
while i < 8:
 i += 2
print(i)
# Out:
# 9

# %%
print(2 < 3 < 5)
# Out:
# True

# %%
for i in range(3):
 print('*'*i)
# Out:
# *
# **

# %%
print(5 and 0)
# Out:
# 0

# %%
a = 6
print(a % 4)
# Out:
# 2

# %%
for i in range(3):
 if i == 2:
  continue
 print(i, end=' ')
# Out:
# 0 1

# %%
print(not False)
# Out:
# True

# %%
i = 0
while i < 2:
 print(i)
 i += 1
# Out:
# 0
# 1

# %%
print(2 + 2 * 3)
# Out:
# 8
